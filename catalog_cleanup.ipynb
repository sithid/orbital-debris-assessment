# %%
import pandas as pd

# %%
soc_catalog_messy = pd.read_csv('data/original/Satellite-Orbital-Catalog.csv')

soc_catalog_messy
# Out:
#        norad_id                  name object_type satellite_constellation  \
# 0           900           CALSPHERE 1     PAYLOAD                   Other
# 1           902           CALSPHERE 2     PAYLOAD                   Other
# 2          1361                 LCS 1     PAYLOAD                   Other
# 3          1512             TEMPSAT 1     PAYLOAD                   Other
# 4          1520          CALSPHERE 4A     PAYLOAD                   Other
# ...         ...                   ...         ...                     ...
# 13376     66418  HULIANWANG DIGUI 13G     UNKNOWN                   Other
# 13377     66419  HULIANWANG DIGUI 13H     UNKNOWN                   Other
# 13378     66420  HULIANWANG DIGUI 13J     UNKNOWN                   Other
# 13379     66454           VIASAT-3 F2     PAYLOAD                   Other
# 13380     66514           SENTINEL-6B     PAYLOAD                   Other
#
#         altitude_km altitude_category  orbital_band congestion_risk  \
# ...

# %%
soc_catalog_messy.columns
# Out:
# Index(['norad_id', 'name', 'object_type', 'satellite_constellation',
#        'altitude_km', 'altitude_category', 'orbital_band', 'congestion_risk',
#        'inclination', 'eccentricity', 'launch_year_estimate',
#        'days_in_orbit_estimate', 'orbit_lifetime_category', 'mean_motion',
#        'epoch', 'data_source', 'snapshot_date', 'country', 'last_seen'],
#       dtype='object')
