# %% [markdown]
# # Orbital Debris SQL Queries
#
# This notebook is intentionally SQL-first and contains query work only (no visualizations).

# %% [markdown]
# ## **Setup And Function Declarations**

# %%
import pandas as pd
import sqlite3 as sql
import utility as utils

orbital_debris_conn = sql.connect('../data/clean/orbital_debris.db')

# Sanity Check - Verify that the database connection is working and that we can retrieve data
sanity_check_no_decayed = utils.query_all_satellites(orbital_debris_conn, include_decayed=False)
display(sanity_check_no_decayed)

sanity_check_all = utils.query_all_satellites(orbital_debris_conn)
display(sanity_check_all)
# Out:
#        norad_id  cospar_id   object_name satellite_name official_name  \
# 4             5  1958-002B    VANGUARD 1           None          None
# 10           11  1959-001A    VANGUARD 2           None          None
# 11           12  1959-001B  VANGUARD R/B           None          None
# 15           16  1958-002A  VANGUARD R/B           None          None
# 19           20  1959-007A    VANGUARD 3           None          None
# ...         ...        ...           ...            ...           ...
# 68356     68539  2026-069B      TACHELES           None          None
# 68357     68540  2026-069C         SWC-1           None          None
# 68358     68541  2026-069D     K-RADCUBE           None          None
# 68359     68571  2026-071A      OBJECT A           None          None
# 68360     68572  2026-071B      OBJECT B           None          None
#
#        object_type            category   ops_status data_status decay_date  \
# 4          PAYLOAD  Inactive Satellite      UNKNOWN        None       None
# 10         PAYLOAD  Inactive Satellite      UNKNOWN        None       None
# 11     ROCKET BODY         Rocket Body      UNKNOWN        None       None
# 15     ROCKET BODY         Rocket Body      UNKNOWN        None       None
# 19         PAYLOAD  Inactive Satellite      UNKNOWN        None       None
# ...            ...                 ...          ...         ...        ...
# 68356      PAYLOAD    Active Satellite  OPERATIONAL        None       None
# 68357      PAYLOAD    Active Satellite  OPERATIONAL        None       None
# 68358      PAYLOAD    Active Satellite  OPERATIONAL        None       None
# 68359      PAYLOAD    Active Satellite  OPERATIONAL        None       None
# 68360  ROCKET BODY         Rocket Body      UNKNOWN        None       None
#
#        ...       users is_commercial is_government is_military is_civil  \
# 4      ...  Commercial             1             0           0        0
# 10     ...  Commercial             1             0           0        0
# 11     ...  Commercial             1             0           0        0
# 15     ...  Commercial             1             0           0        0
# 19     ...  Commercial             1             0           0        0
# ...    ...         ...           ...           ...         ...      ...
# 68356  ...       Civil             0             0           0        1
# 68357  ...  Commercial             1             0           0        0
# 68358  ...  Government             0             1           0        0
# 68359  ...    Military             0             0           1        0
# 68360  ...    Military             0             0           1        0
#
#                                               contractor  \
# 4                                               Amsat-NA
# 10                                              Amsat-NA
# 11                                              Amsat-NA
# 15                                              Amsat-NA
# 19                                              Amsat-NA
# ...                                                  ...
# 68356  Institute of Aeronautics and Astronautics, Tec...
# 68357  Space Research Institute, King Abdulaziz City ...
# 68358  Korea Aerospace Research Institute (KARI)/ EAD...
# 68359  NPO/PM - Scientific Research Institute for Pre...
# 68360  NPO/PM - Scientific Research Institute for Pre...
#
#                   contractor_country  launch_date  launch_year  launch_site
# 4                                USA   1958-03-17         1958        AFETR
# 10                               USA   1959-02-17         1959        AFETR
# 11                               USA   1959-02-17         1959        AFETR
# 15                               USA   1958-03-17         1958        AFETR
# 19                               USA   1959-09-18         1959        AFETR
# ...                              ...          ...          ...          ...
# 68356                        Germany   2026-04-01         2026        AFETR
# 68357                   Saudi Arabia   2026-04-01         2026        AFETR
# 68358  South Korea/France/UK/Germany   2026-04-01         2026        AFETR
# 68359                         Russia   2026-04-03         2026        PLMSC
# 68360                         Russia   2026-04-03         2026        PLMSC
#
# [33403 rows x 50 columns]
#        norad_id  cospar_id object_name satellite_name official_name  \
# 0             1  1957-001A    SL-1 R/B           None          None
# 1             2  1957-001B   SPUTNIK 1           None          None
# 2             3  1957-002A   SPUTNIK 2           None          None
# 3             4  1958-001A  EXPLORER 1           None          None
# 4             5  1958-002B  VANGUARD 1           None          None
# ...         ...        ...         ...            ...           ...
# 68356     68539  2026-069B    TACHELES           None          None
# 68357     68540  2026-069C       SWC-1           None          None
# 68358     68541  2026-069D   K-RADCUBE           None          None
# 68359     68571  2026-071A    OBJECT A           None          None
# 68360     68572  2026-071B    OBJECT B           None          None
#
#        object_type            category   ops_status data_status  decay_date  \
# 0      ROCKET BODY         Rocket Body      DECAYED        None  1957-12-01
# 1          PAYLOAD  Inactive Satellite      DECAYED        None  1958-01-03
# 2          PAYLOAD  Inactive Satellite      DECAYED        None  1958-04-14
# 3          PAYLOAD  Inactive Satellite      DECAYED        None  1970-03-31
# 4          PAYLOAD  Inactive Satellite      UNKNOWN        None        None
# ...            ...                 ...          ...         ...         ...
# 68356      PAYLOAD    Active Satellite  OPERATIONAL        None        None
# 68357      PAYLOAD    Active Satellite  OPERATIONAL        None        None
# 68358      PAYLOAD    Active Satellite  OPERATIONAL        None        None
# 68359      PAYLOAD    Active Satellite  OPERATIONAL        None        None
# 68360  ROCKET BODY         Rocket Body      UNKNOWN        None        None
#
#        ...       users is_commercial is_government is_military is_civil  \
# 0      ...    Military             0             0           1        0
# 1      ...    Military             0             0           1        0
# 2      ...    Military             0             0           1        0
# 3      ...  Commercial             1             0           0        0
# 4      ...  Commercial             1             0           0        0
# ...    ...         ...           ...           ...         ...      ...
# 68356  ...       Civil             0             0           0        1
# 68357  ...  Commercial             1             0           0        0
# 68358  ...  Government             0             1           0        0
# 68359  ...    Military             0             0           1        0
# 68360  ...    Military             0             0           1        0
#
#                                               contractor  \
# 0      NPO/PM - Scientific Research Institute for Pre...
# 1      NPO/PM - Scientific Research Institute for Pre...
# 2      NPO/PM - Scientific Research Institute for Pre...
# 3                                               Amsat-NA
# 4                                               Amsat-NA
# ...                                                  ...
# 68356  Institute of Aeronautics and Astronautics, Tec...
# 68357  Space Research Institute, King Abdulaziz City ...
# 68358  Korea Aerospace Research Institute (KARI)/ EAD...
# 68359  NPO/PM - Scientific Research Institute for Pre...
# 68360  NPO/PM - Scientific Research Institute for Pre...
#
#                   contractor_country  launch_date  launch_year  launch_site
# 0                             Russia   1957-10-04         1957        TYMSC
# 1                             Russia   1957-10-04         1957        TYMSC
# 2                             Russia   1957-11-03         1957        TYMSC
# 3                                USA   1958-02-01         1958        AFETR
# 4                                USA   1958-03-17         1958        AFETR
# ...                              ...          ...          ...          ...
# 68356                        Germany   2026-04-01         2026        AFETR
# 68357                   Saudi Arabia   2026-04-01         2026        AFETR
# 68358  South Korea/France/UK/Germany   2026-04-01         2026        AFETR
# 68359                         Russia   2026-04-03         2026        PLMSC
# 68360                         Russia   2026-04-03         2026        PLMSC
#
# [68361 rows x 50 columns]

# %% [markdown]
# ## Primary Question 1: Growth and Decoupling Baseline
# At what year does the present day in-orbit population stop following a legacy linear pattern and transition into a modern accelerating pattern?

# %% [markdown]
# ## **Primary Question 2: High-Risk Distribution by Altitude Band**
# How are high-risk objects (by velocity and kinetic energy) distributed across orbit classes and altitude bands, especially in the 400 - 600 km LEO?

# %% [markdown]
# ## **Primary Question 3: Zombie Concentration by Owner**

# %% [markdown]
# ## **Secondary: Object Type × Operational Status**

# %% [markdown]
# ## **Secondary: User Category Profile**

# %% [markdown]
# ## **Extra Questions!**
