# %% [markdown]
# # Orbital Debris Story: Primary and Secondary Questions
#
# **Database:** orbital_debris.db (SQLite)
# **Docs:** See `docs/schema` for full table and field details. See notebook 05 for exploratory work that shaped these questions.
#
# **Goal:** Answer the project's primary and secondary research questions with focused SQL queries and targeted visuals. Each section states the question, runs the query, and presents the result.
#
#
# ### Primary Questions
# 1. At what year did orbital growth decouple from a historical linear trend and transition into an exponential trajectory?
# 2. How are high-risk objects distributed across orbit classes and altitude bands, especially in 400–600 km LEO?
# 3. Which ownership/operator groups contribute most to non-operational "zombie" payload concentrations?
#
# ### Secondary Questions
# 1. How do launch cohorts and post-2014 deployment patterns affect congestion intensity?
# 2. How do object type and operational status relate to kinetic risk?
# 3. Do user categories (commercial, government, military, civil) show distinct risk profiles?

# %% [markdown]
# ## Primary Question 1: Growth and Decoupling Baseline
#
#
# **At what year did orbital growth decouple from a historical linear trend and transition into an exponential trajectory?**
#
# To answer this, we analyzed evidence from the exploratory data analysis (EDA) in notebook 05:
#
# **Launch Year Trends:**
#
# The bar charts below show the number of payloads, rocket bodies, and debris objects added to orbit each year. This separation clarifies the contributions of each object type to overall orbital growth.
#
# - **Payloads:**
#   ![Payloads per Year](../charts/payloads_per_year_exp.png)
#   >After 2014, the number of payloads launched accelerates, marking a shift to exponential growth.
#
# - **Rocket Bodies:**
#   ![Rocket Bodies per Year](../charts/rocket_bodies_per_year_exp.png)
#   >The number of rocket bodies left in orbit peaked in the mid-1980s, then declined and stabilized after 2000, with only a slight uptick in recent years.
#
# - **Debris:**
#   ![Debris per Year](../charts/debris_per_year_exp.png)
#   > Debris object counts show a steady but relatively low increase over the decades, punctuated by major spikes in 1965, 1982, 1993, and especially 2000. After 2000, debris additions decline sharply, with only occasional spikes in subsequent years. Unlike payloads, debris does not follow an exponential growth pattern; its increases are driven by discrete events rather than continuous launch activity.
#
# **Object Type Distribution Over Time:**
#
# The stacked area and bar charts show how the mix of payloads, rocket bodies, and debris evolved. The growing share of debris and payloads in recent years supports the idea that not only the number but also the composition of orbital objects changed, contributing to increased congestion.
#
# ![Object Type Distribution Trends](../charts/object_type_distribution_trends_exp.png)
#
# ![Object Type Distribution Bar](../charts/object_type_distribution_bar_exp.png)
#
# **Linear vs Exponential Trend: In-Orbit Object Growth:**
#
# This section provides the most direct evidence. By fitting both linear and exponential models to the in-orbit object count, we identified a data-driven split year where the growth rate transitions from steady (linear) to rapid (exponential). The chart marks this split year and overlays the fitted trends, visually confirming the acceleration.
#
# ![Linear vs Exponential Trend](../charts/linear_vs_exponential_trend_exp.png)
#
# **Deployment Patterns and the Growth Shift:**
#
# The deployment patterns analysis further clarifies the nature of the decoupling point. Before the split, launches produced more debris and relatively fewer payloads, with rocket bodies present in numbers similar to payloads. After 2014, the pattern shifts dramatically: payload launches surge, while debris and rocket bodies per launch drop sharply. The deployment patterns visual (see below) shows both the absolute counts and the share of each object type by era, highlighting how modern deployment practices—such as rideshare missions and batch deployments—have increased payloads while reducing associated debris and rocket bodies. This shift in deployment strategy is a key driver of the exponential growth in payloads and the changing composition of objects in orbit.
#
# ![Deployment Patterns by Era](../charts/deployment_patterns_exp.png)
#
# **Conclusion:**
#
# The convergence of these analyses points to a clear decoupling point in the mid-2010s, with the most significant shift occurring around 2014. This marks the onset of exponential growth in orbital objects, driven primarily by a surge in payload launches and changing deployment patterns. Modern deployment strategies—such as rideshare missions and batch deployments—have dramatically increased the number of payloads while reducing the number of rocket bodies and debris per launch. The deployment patterns analysis shows that, after 2014, the composition of objects in orbit shifted: payloads now dominate new additions, while debris and rocket bodies have declined or stabilized. Statistical modeling, launch activity, object type trends, and deployment practices together provide clear evidence for this transition and help explain the mechanisms behind the exponential growth in orbital congestion.

# %% [markdown]
# ## Primary Question 2: High-Risk Object Distribution by Altitude Band and Orbit Class
#
#
# **At what altitudes and in which orbit classes are high-risk objects most concentrated, especially in the congested 400–600 km LEO region?**
#
#
# **High-Risk Object Criteria and Clustering**
#
#
# Understanding where the most dangerous objects are clustered is critical for managing collision risk, prioritizing mitigation, and shaping policy. High-risk objects—those with the greatest mass and kinetic energy—pose the greatest threat of catastrophic fragmentation events, which can multiply debris and threaten all space operations. Objects were classified as "Extremely High Risk" based on kinetic energy and mass thresholds, using the latest available orbital and physical data.
#
#
# Out of all in-orbit objects with risk data, only a small fraction meet the "Extremely High Risk" criteria. However, these objects account for a disproportionate share of the total collision hazard. Their distribution is not uniform: they cluster in specific altitude bands and orbit classes, creating risk hotspots.
#
#
# **High-Risk Objects in the 400–600 km LEO Band**
#
#
# The bar chart below displays the distribution of high-risk objects specifically within the 400–600 km low Earth orbit (LEO) band. Each bar represents a 25 km altitude segment, with the x-axis showing altitude (in km) and the y-axis indicating the number of high-risk objects in each segment. This visualization highlights how high-risk objects are concentrated at particular altitudes within this heavily utilized region, which is a focal point for commercial megaconstellations and sun-synchronous orbits.
#
#
# ![High-Risk Objects by Altitude Band](../charts/high_risk_banded_exp.png)
#
#
# > The 400–600 km band is not only the most crowded, but also the most dynamic, with frequent launches and decays. Its popularity for Earth observation and communications drives persistent congestion, increasing the likelihood of close approaches and potential collisions.
#
#
# **High-Risk Objects by Orbit Class and Altitude Band**
#
#
# The stacked bar chart below breaks down high-risk objects by orbit class within each altitude band. LEO overwhelmingly dominates the high-risk population, especially in the most crowded bands. However, smaller but non-negligible populations exist in higher orbits (MEO, GEO), where debris removal is more challenging and collision consequences can be long-lasting.
#
#
# ![High-Risk Object Distribution by Altitude Band and Orbit Class](../charts/high_risk_object_distribution_alt_bands_exp.png)
#
#
# > LEO stands out as the main stage for collision risk because it hosts the largest number of satellites and debris. Objects in this region travel quickly and cross paths often, leading to more chances for close calls and collisions. Although objects in LEO don’t remain in orbit as long as those higher up, the sheer density of high-risk objects makes it the most important area for preventing accidents and keeping space safe for everyone.
#
#
# **High-Risk Objects by Orbit Class**
#
#
# The chart below provides a direct view of how high-risk objects are distributed across orbit classes. LEO contains the vast majority, but MEO and GEO also host a non-trivial number of high-risk objects, underscoring the need for vigilance beyond LEO.
#
#
# ![High-Risk Objects by Orbit Class](../charts/hr_orbit_class_exp.png)
#
#
# > The vast majority of high-risk objects are concentrated in LEO, making it the primary focus for collision prevention. However, the fact that MEO and GEO also contain high-risk objects highlights the need for careful risk management across all regions of Earth’s orbit—not just the most crowded ones.
#
#
# **Mass Distribution of High-Risk Objects**
#
#
# The following charts show that the most massive and energetic high-risk objects are concentrated in specific bands and orbit classes. These objects, often defunct satellites or spent rocket bodies, have the potential to generate thousands of new debris fragments if involved in a collision.
#
#
# ![High-Risk Mass by Orbit Class (Strip)](../charts/high_risk_mass_strip_by_orbit_class.png)
# ![High-Risk Mass by Orbit Class (Histogram)](../charts/high_risk_mass_hist_by_orbit_class.png)
#
#
# > The mass distribution is highly skewed, with a small number of extremely massive objects representing outsized risk. These are priority targets for active debris removal and monitoring.
#
#
# **Debris Clouds and Collision Risk**
#
#
# While extremely high-risk objects are rare and massive, the vast majority of orbital debris consists of much smaller fragments. These objects may not individually pose catastrophic risk, but their sheer numbers and spatial clustering create dangerous “debris clouds” that raise the probability of collisions for all satellites and missions.
#
#
# **Debris Generation Over Time**
#
#
# The chart below shows the annual number of debris objects added to orbit. Major spikes correspond to fragmentation events, anti-satellite tests, or major collisions. The persistent addition of debris over decades has created dense clouds, especially in low Earth orbit (LEO).
#
#
# ![Debris Objects Added per Year](../charts/debris_per_year_exp.png)
#
#
# > Debris generation is not steady—large spikes reflect major events that instantly multiply the debris population. Even in years without major events, the background rate of debris creation keeps the orbital environment hazardous.
#
#
# **Object Type Distribution Over Time**
#
#
# The stacked area chart below shows how the proportion of debris, payloads, and rocket bodies in orbit has changed over time. The growing share of debris highlights the cumulative effect of decades of fragmentation and abandonment.
#
#
# ![Object Type Distribution Over Time (Area Chart)](../charts/object_type_distribution_exp.png)
#
#
# > Debris now makes up a significant fraction of all tracked objects in orbit. This cumulative burden increases collision risk for all space users, especially in crowded LEO bands.
#
#
# ---
#
#
# **Conclusion:**
#
#
# High-risk objects are highly concentrated in the 400–600 km LEO band and within the LEO orbit class overall, making these regions the primary focus for risk mitigation and traffic management. However, the cumulative, systemic risk posed by debris clustering is equally critical: even if individual fragments are small, their numbers and spatial concentration make them a primary driver of collision probability and long-term orbital sustainability. The evidence shows that both massive, energetic objects and dense debris clouds must be addressed to preserve the safety and sustainability of the orbital environment.

# %% [markdown]
# ## Primary Question 3: Who Leaves the Most "Zombie" Satellites in Space?
#
# **Which ownership or operator groups are responsible for the most non-working "zombie" satellites?**
#
# When satellites stop working but stay in orbit, they become "zombies." These dead satellites can’t move out of the way or avoid crashes. They take up space and make it more dangerous for working satellites. Knowing which countries or companies have left the most zombie satellites helps us understand who should help fix the problem.
#
# ---
#
# **How Many Satellites Are Still Working?**
#
# The chart below shows the status of all satellites still in orbit. Most are working (over 14,000), but more than 3,000 are either dead, partly working, or their status is unknown. Even though most satellites are still active, the large number of zombies and unknowns adds to the risk of crashes.
#
# ![Payload Operational Status Distribution](../charts/ops_status_distribution_exp.png)
#
# > Most satellites are working, but over 3,000 are either non-operational, partly working, or their status is unknown—this is still a big problem for space safety.
#
# ---
#
# **Which Countries or Groups Have the Most Zombies?**
#
# The chart below shows which owner or operator groups have left the most dead satellites (“zombies”) in space.
#
# Each bar is colored by the “Country Operator” (shown in the legend). For example, US, ITSO, and GLOB are all blue for the USA, CIS is red for Russia, PRC is tan for China, and JPN is orange for multinational. This helps you see not just which group, but also which country or region is responsible.
#
# The US and Russia (CIS) stand far ahead of everyone else, with much higher zombie counts. Japan and the next few groups (ITSO, PRC, GLOB) follow, but their numbers are much lower. After these, the rest of the groups trail off with only a small number of zombie satellites.
#
# ![Top Zombie Payload Contributors](../charts/zombie_top_contributors_exp.png)
#
# > The US and Russia together have left far more zombie satellites than any other group. Focusing cleanup or new rules on these two could make the biggest difference for space safety.
#
# ---
#
# **Which Companies or Organizations Built the Most Zombies?**
#
# The chart below shows the top 20 companies or organizations (“contractors”) that have built or managed the most dead satellites, no matter which country they’re from.
#
# AMSAT-NA and NPO/PM stand out with a strong lead—AMSAT-NA has 450 zombie satellites, and NPO/PM has just over 310. After these two, there’s a sharp drop: Alcatel, NASA/Goddard, and Space Systems follow, but with much lower numbers. From there, the chart stair-steps down from around 100 to nearly zero, showing that most contractors have left far fewer dead satellites in orbit.
#
# ![Top Zombie Payload Contributors by Contractor](../charts/zombie_top_contractor_contributors_exp.png)
#
# > Just a few companies or organizations are responsible for a large share of the dead satellites. Focusing on better end-of-life practices with these top contractors could make a big difference in reducing space congestion.
#
# ---
#
# **How Do the Top Groups Compare?**
#
# The chart below shows how the top owner/operator groups stack up in terms of their satellites’ status: how many are still working, how many are dead (“zombies”), and how many have another or unknown status. Each group’s bar is split into different colors for each status, making it easy to spot which groups have a higher share of zombies.
#
# - The US stands out with a huge number of operational satellites—a little over 11,000—while the numbers of zombies, partial, or unknown status satellites are much smaller (about 400–450 in each category).
# - CIS (Russia) has a much smaller total fleet, but its mix is different: it has about the same number of operational and zombie satellites (around 300 each), and a little over 1,000 unknown status satellites.
# - PRC (China) has over 1,250 operational satellites and very few (20–60) in other status categories.
# - The UK trails the PRC with just over 600 operational payloads, while Japan and the other groups have much lower counts in all categories.
# - The “Other” category includes about 900 operational satellites, roughly 350 zombies, and 25–50 in unknown or other statuses.
#
# ![Owner/Operator Status Mix](../charts/owner_status_mix_exp.png)
#
# > Some groups have a much higher share of zombies, while others do a better job keeping their satellites working. This mix shows where improvements in satellite management could have the biggest impact.
#
# ---
#
# **Quick Facts About Satellites in Orbit**
#
# The numbers below give a snapshot of the current state of satellites and other objects in orbit. The stats speak for themselves—there are far more working satellites than zombies, but the number of dead and unknown-status satellites is still significant.
#
# | What? | How Many? |
# | :----------------------------- | ----: |
# | Unique owner/operator pairs | 105 |
# | Total satellites in orbit | 18,384 |
# | Still working | 14,855 |
# | Dead (zombie) | 1,466 |
# | Misc status | 515 |
# | Unknown status | 1,548 |
# | Total Other Status | 3,529 |
# | Non-satellites (other objects) | 15,008 |
#
# ---
#
# **Who Owns the Most Satellites?**
#
# The bar and pie charts below show which groups have the largest number of satellites in orbit. The US is the clear leader, with over 12,000 satellites—far more than any other group. CIS (Russia) comes next, with close to 2,000, and PRC (China) follows with about 1,600. The UK has just under 1,000. After that, each group from Japan (JPN) down to ESA, ITSO, and others has around 100 satellites or fewer. The “Other” category, which combines many smaller groups, has about 1,200 satellites in total.
#
# The bar chart makes it easy to compare the numbers for each group.
# The pie chart shows what share of the total each group owns.
# This helps us see that the satellite population is very top-heavy: just a few groups own the vast majority, while most others have only a small presence in orbit.
#
# ![Top Owners by Total Payloads](../charts/contribution_report_top_owners_exp.png)
#
# ![Top Owners by % of Total In-Orbit Payloads](../charts/contribution_report_top_owners_pie_exp.png)
#
# > The biggest owners don’t always have the most zombies. Some are better at managing their satellites than others.
#
# ---
#
# **Top 10 Owners: Satellite Stats**
#
# The table below summarizes the top satellite owners in orbit, showing how many satellites each group has, how many are still working, how many are “zombies” (dead), and other status details. It also shows each group’s share of the total, plus the first and most recent year they launched satellites.
#
# - The US leads by a huge margin, with over 12,000 satellites—more than two-thirds of all in orbit.
# - CIS (Russia) is next, with about 1,700 satellites, but a much higher share of zombies and unknowns.
# - PRC (China) and the UK follow, with 1,300 and 700 satellites, respectively.
# - All other groups have much smaller fleets, often under 200 satellites each.
# - The “Other” category combines many smaller owners, together making up about 1,300 satellites.
#
#
# | Owner | Country Operator | Operational Payload Count | Zombie Payload Count | Misc Status Count | Unknown Status Count | Total Payloads | % of Total Payloads | First Year | Last Year |
# | :---- | :--------------- | ------------: | ---------: | ---------: | ---------: | --------: | -------: | --------: | --------: |
# | **US** | **USA** | **11165** | **450** | **432** | **403** | **12450** | **67.72%** | **1958** | **2026** |
# | **CIS** | **RUSSIA** | **345** | **310** | **12** | **1021** | **1688** | **9.18%** | **1959** | **2026** |
# | **PRC** | **CHINA** | **1268** | **62** | **23** | **23** | **1376** | **7.48%** | **1970** | **2026** |
# | **UK** | **UNITED KINGDOM** | **690** | **18** | **5** | **7** | **720** | **3.92%** | **1969** | **2026** |
# | **JPN** | **MULTINATIONAL** | **121** | **84** | **6** | **12** | **223** | **1.21%** | **1971** | **2026** |
# | **TBD** | **USA** | **124** | **17** | **0** | **0** | **141** | **0.77%** | **1998** | **2026** |
# | **FR** | **FRANCE/ITALY/BELGIUM/SPAIN/GREECE** | **72** | **34** | **0** | **19** | **125** | **0.68%** | **1965** | **2025** |
# | **IND** | **INDIA** | **72** | **40** | **5** | **1** | **118** | **0.64%** | **1981** | **2025** |
# | **ESA** | **ESA** | **70** | **32** | **5** | **4** | **111** | **0.60%** | **1977** | **2026** |
# | **ITSO** | **USA** | **36** | **63** | **1** | **0** | **100** | **0.54%** | **1965** | **2023** |
# | **OTHER** | **95 FILTERED OWNER/OPERATORS** | **892** | **356** | **26** | **58** | **1332** | **7.25%** | **1957** | **2026** |
#
# ---
#
# **Conclusion**
#
# The analysis of non-operational (“zombie”) satellites reveals that while most satellites remain active, over 3,000 are dead, partly working, or of unknown status—posing a measurable risk to orbital safety. The US, CIS (Russia), and PRC (China) dominate satellite ownership, but their management practices differ, with CIS and several smaller groups having higher shares of zombies and unknowns. This distribution is shaped by historical launch activity, end-of-life practices, and the policies of a few dominant owners and contractors. The evidence indicates that targeted improvements—such as stricter end-of-life requirements, active removal, and better tracking—by the largest contributors would yield the greatest reduction in orbital risk and are essential for long-term sustainability.

# %% [markdown]
# ## Secondary Question 1: Launch Cohorts and Post-2014 Congestion
#
# **How do launch cohorts and post-2014 deployment patterns affect congestion intensity?**
#
# Compare the volume and type mix of objects launched before and after the 2014 decoupling point to show how deployment patterns changed when growth accelerated.

# %% [markdown]
# ## Secondary Question 2: Object Type × Operational Status and Kinetic Risk
#
# **How do object type (PAYLOAD, ROCKET BODY, DEBRIS) and operational status relate to kinetic risk?**
#
# Compare kinetic energy across object types using status systems that match each type — operational status for payloads, lifecycle state for rocket bodies and debris.

# %% [markdown]
# ## Secondary Question 3: User Category Risk Profiles
#
# **Do user categories (commercial, government, military, civil) show distinct risk profiles?**
#
# Compare user categories on kinetic energy, operational status mix, and satellite age to see whether certain sectors carry disproportionate collision risk.
