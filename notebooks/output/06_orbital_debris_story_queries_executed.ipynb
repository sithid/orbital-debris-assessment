# %% [markdown]
# # Orbital Debris SQL Queries
#
# This notebook is intentionally SQL-first and contains query work only (no visualizations).

# %% [markdown]
# ## **Setup And Function Declarations**

# %%
import pandas as pd
import sqlite3 as sql
import utility as utils

orbital_debris_conn = sql.connect('../data/clean/orbital_debris.db')

# Sanity Check - Verify that the database connection is working and that we can retrieve data
sanity_check = utils.query_all_satellites(orbital_debris_conn)

sanity_check
# Out:
#        norad_id  cospar_id               object_name  launch_year launch_date  \
# 0             5  1958-002B                VANGUARD 1         1958  1958-03-17
# 1            11  1959-001A                VANGUARD 2         1959  1959-02-17
# 2            12  1959-001B              VANGUARD R/B         1959  1959-02-17
# 3            16  1958-002A              VANGUARD R/B         1958  1958-03-17
# 4            20  1959-007A                VANGUARD 3         1959  1959-09-18
# ...         ...        ...                       ...          ...         ...
# 33343     68377  2026-062A  SUPERVIEW NEO-2 OBJECT A         2026  2026-03-25
# 33344     68378  2026-062B  SUPERVIEW NEO-2 OBJECT B         2026  2026-03-25
# 33345     68379  2026-062C                 CZ-2D R/B         2026  2026-03-25
# 33346     68405  2026-064A                 SHIYAN-33         2026  2026-03-27
# 33347     68408  2026-065A                  OBJECT A         2026  2026-03-28
#
#       launch_site owner country_operator  object_type
# 0           AFETR    US              USA      PAYLOAD
# 1           AFETR    US              USA      PAYLOAD
# 2           AFETR    US              USA  ROCKET BODY
# 3           AFETR    US              USA  ROCKET BODY
# 4           AFETR    US              USA      PAYLOAD
# ...           ...   ...              ...          ...
# 33343       TAISC   PRC            CHINA      PAYLOAD
# 33344       TAISC   PRC            CHINA      PAYLOAD
# 33345       TAISC   PRC            CHINA  ROCKET BODY
# 33346         JSC   PRC            CHINA      PAYLOAD
# 33347        RLLB   ESA              ESA      PAYLOAD
#
# [33348 rows x 9 columns]

# %% [markdown]
# ## Primary Question 1: Growth and Decoupling Baseline
# At what year does the present day in-orbit population stop following a legacy linear pattern and transition into a modern accelerating pattern?

# %% [markdown]
# ## **Primary Question 2: High-Risk Distribution by Altitude Band**
# How are high-risk objects (by velocity and kinetic energy) distributed across orbit classes and altitude bands, especially in the 400 - 600 km LEO?

# %% [markdown]
# ## **Primary Question 3: Zombie Concentration by Owner**

# %% [markdown]
# ## **Secondary: Object Type × Operational Status**

# %% [markdown]
# ## **Secondary: User Category Profile**

# %% [markdown]
# ## **Extra Questions!**
