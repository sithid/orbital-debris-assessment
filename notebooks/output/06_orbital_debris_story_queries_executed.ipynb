# %% [markdown]
# # Orbital Debris SQL Queries
#
# This notebook is intentionally SQL-first and contains query work only (no visualizations).

# %% [markdown]
# ## **Setup And Function Declarations**

# %%
import pandas as pd
import sqlite3 as sql
import utility as utils

orbital_debris_conn = sql.connect('../data/clean/orbital_debris.db')

# Sanity Check - Verify that the database connection is working and that we can retrieve data
sanity_check = utils.query_all_satellites(orbital_debris_conn)

sanity_check
# Out:
#        norad_id  cospar_id               object_name satellite_name  \
# 0             5  1958-002B                VANGUARD 1           None
# 1            11  1959-001A                VANGUARD 2           None
# 2            12  1959-001B              VANGUARD R/B           None
# 3            16  1958-002A              VANGUARD R/B           None
# 4            20  1959-007A                VANGUARD 3           None
# ...         ...        ...                       ...            ...
# 33343     68377  2026-062A  SUPERVIEW NEO-2 OBJECT A           None
# 33344     68378  2026-062B  SUPERVIEW NEO-2 OBJECT B           None
# 33345     68379  2026-062C                 CZ-2D R/B           None
# 33346     68405  2026-064A                 SHIYAN-33           None
# 33347     68408  2026-065A                  OBJECT A           None
#
#       official_name  object_type            category   ops_status data_status  \
# 0              None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# 1              None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# 2              None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 3              None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 4              None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# ...             ...          ...                 ...          ...         ...
# 33343          None      PAYLOAD    Active Satellite  OPERATIONAL        None
# 33344          None      PAYLOAD    Active Satellite  OPERATIONAL        None
# 33345          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 33346          None      PAYLOAD    Active Satellite  OPERATIONAL        None
# 33347          None      PAYLOAD    Active Satellite  OPERATIONAL        None
#
#        in_orbit  ...       users is_commercial is_government is_military  \
# 0             1  ...       Civil             1             1           1
# 1             1  ...       Civil             1             1           1
# 2             1  ...       Civil             1             1           1
# 3             1  ...       Civil             1             1           1
# 4             1  ...       Civil             1             1           1
# ...         ...  ...         ...           ...           ...         ...
# 33343         1  ...  Government             1             1           1
# 33344         1  ...  Government             1             1           1
# 33345         1  ...  Government             1             1           1
# 33346         1  ...  Government             1             1           1
# 33347         1  ...  Government             1             1           0
#
#        is_civil                               contractor  contractor_country  \
# 0             1                                 Amsat-NA                 USA
# 1             1                                 Amsat-NA                 USA
# 2             1                                 Amsat-NA                 USA
# 3             1                                 Amsat-NA                 USA
# 4             1                                 Amsat-NA                 USA
# ...         ...                                      ...                 ...
# 33343         1              Chinese Academy of Sciences               China
# 33344         1              Chinese Academy of Sciences               China
# 33345         1              Chinese Academy of Sciences               China
# 33346         1              Chinese Academy of Sciences               China
# 33347         1  Dornier Systems (and 46 subcontractors)       International
#
#        launch_date  launch_year  launch_site
# 0       1958-03-17         1958        AFETR
# 1       1959-02-17         1959        AFETR
# 2       1959-02-17         1959        AFETR
# 3       1958-03-17         1958        AFETR
# 4       1959-09-18         1959        AFETR
# ...            ...          ...          ...
# 33343   2026-03-25         2026        TAISC
# 33344   2026-03-25         2026        TAISC
# 33345   2026-03-25         2026        TAISC
# 33346   2026-03-27         2026          JSC
# 33347   2026-03-28         2026         RLLB
#
# [33348 rows x 48 columns]

# %% [markdown]
# ## Primary Question 1: Growth and Decoupling Baseline
# At what year does the present day in-orbit population stop following a legacy linear pattern and transition into a modern accelerating pattern?

# %% [markdown]
# ## **Primary Question 2: High-Risk Distribution by Altitude Band**
# How are high-risk objects (by velocity and kinetic energy) distributed across orbit classes and altitude bands, especially in the 400 - 600 km LEO?

# %% [markdown]
# ## **Primary Question 3: Zombie Concentration by Owner**

# %% [markdown]
# ## **Secondary: Object Type × Operational Status**

# %% [markdown]
# ## **Secondary: User Category Profile**

# %% [markdown]
# ## **Extra Questions!**
