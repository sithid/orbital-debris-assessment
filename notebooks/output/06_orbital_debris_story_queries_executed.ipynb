# %% [markdown]
# # Orbital Debris SQL Queries
#
# This notebook is intentionally SQL-first and contains query work only (no visualizations).

# %% [markdown]
# ## **Setup And Function Declarations**

# %%
import pandas as pd
import sqlite3 as sql
import utility as utils

orbital_debris_conn = sql.connect('../data/clean/orbital_debris.db')

# Sanity Check - Verify that the database connection is working and that we can retrieve data
sanity_check_no_decayed = utils.query_all_satellites(orbital_debris_conn, include_decayed=False)
display(sanity_check_no_decayed)

sanity_check_all = utils.query_all_satellites(orbital_debris_conn)
display(sanity_check_all)
# Out:
#        norad_id  cospar_id              object_name satellite_name  \
# 4             5  1958-002B               VANGUARD 1           None
# 10           11  1959-001A               VANGUARD 2           None
# 11           12  1959-001B             VANGUARD R/B           None
# 15           16  1958-002A             VANGUARD R/B           None
# 19           20  1959-007A               VANGUARD 3           None
# ...         ...        ...                      ...            ...
# 68325     68411  2026-065D  ELECTRON KICK STAGE R/B           None
# 68326     68412  2026-066A         XINZHENGCHENG-01           None
# 68327     68413  2026-066B             LIJIAN-2 R/B           None
# 68328     68537  2026-061S                 SL-4 R/B           None
# 68329     68538  2026-069A                ARTEMIS 2           None
#
#       official_name  object_type            category   ops_status data_status  \
# 4              None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# 10             None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# 11             None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 15             None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 19             None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# ...             ...          ...                 ...          ...         ...
# 68325          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 68326          None      PAYLOAD    Active Satellite  OPERATIONAL        None
# 68327          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 68328          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 68329          None      PAYLOAD    Active Satellite  OPERATIONAL        None
#
#       decay_date  ...       users is_commercial is_government is_military  \
# 4           None  ...       Civil             1             1           1
# 10          None  ...       Civil             1             1           1
# 11          None  ...       Civil             1             1           1
# 15          None  ...       Civil             1             1           1
# 19          None  ...       Civil             1             1           1
# ...          ...  ...         ...           ...           ...         ...
# 68325       None  ...       Civil             1             1           1
# 68326       None  ...  Government             1             1           1
# 68327       None  ...  Government             1             1           1
# 68328       None  ...    Military             1             1           1
# 68329       None  ...       Civil             1             1           1
#
#       is_civil                                         contractor  \
# 4            1                                           Amsat-NA
# 10           1                                           Amsat-NA
# 11           1                                           Amsat-NA
# 15           1                                           Amsat-NA
# 19           1                                           Amsat-NA
# ...        ...                                                ...
# 68325        1                                           Amsat-NA
# 68326        1                        Chinese Academy of Sciences
# 68327        1                        Chinese Academy of Sciences
# 68328        1  NPO/PM - Scientific Research Institute for Pre...
# 68329        1                                           Amsat-NA
#
#        contractor_country  launch_date  launch_year  launch_site
# 4                     USA   1958-03-17         1958        AFETR
# 10                    USA   1959-02-17         1959        AFETR
# 11                    USA   1959-02-17         1959        AFETR
# 15                    USA   1958-03-17         1958        AFETR
# 19                    USA   1959-09-18         1959        AFETR
# ...                   ...          ...          ...          ...
# 68325                 USA   2026-03-28         2026         RLLB
# 68326               China   2026-03-30         2026          JSC
# 68327               China   2026-03-30         2026          JSC
# 68328              Russia   2026-03-23         2026        PLMSC
# 68329                 USA   2026-04-01         2026        AFETR
#
# [33383 rows x 49 columns]
#        norad_id  cospar_id              object_name satellite_name  \
# 0             1  1957-001A                 SL-1 R/B           None
# 1             2  1957-001B                SPUTNIK 1           None
# 2             3  1957-002A                SPUTNIK 2           None
# 3             4  1958-001A               EXPLORER 1           None
# 4             5  1958-002B               VANGUARD 1           None
# ...         ...        ...                      ...            ...
# 68325     68411  2026-065D  ELECTRON KICK STAGE R/B           None
# 68326     68412  2026-066A         XINZHENGCHENG-01           None
# 68327     68413  2026-066B             LIJIAN-2 R/B           None
# 68328     68537  2026-061S                 SL-4 R/B           None
# 68329     68538  2026-069A                ARTEMIS 2           None
#
#       official_name  object_type            category   ops_status data_status  \
# 0              None  ROCKET BODY         Rocket Body      DECAYED        None
# 1              None      PAYLOAD  Inactive Satellite      DECAYED        None
# 2              None      PAYLOAD  Inactive Satellite      DECAYED        None
# 3              None      PAYLOAD  Inactive Satellite      DECAYED        None
# 4              None      PAYLOAD  Inactive Satellite      UNKNOWN        None
# ...             ...          ...                 ...          ...         ...
# 68325          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 68326          None      PAYLOAD    Active Satellite  OPERATIONAL        None
# 68327          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 68328          None  ROCKET BODY         Rocket Body      UNKNOWN        None
# 68329          None      PAYLOAD    Active Satellite  OPERATIONAL        None
#
#        decay_date  ...       users is_commercial is_government is_military  \
# 0      1957-12-01  ...    Military             1             1           1
# 1      1958-01-03  ...    Military             1             1           1
# 2      1958-04-14  ...    Military             1             1           1
# 3      1970-03-31  ...       Civil             1             1           1
# 4            None  ...       Civil             1             1           1
# ...           ...  ...         ...           ...           ...         ...
# 68325        None  ...       Civil             1             1           1
# 68326        None  ...  Government             1             1           1
# 68327        None  ...  Government             1             1           1
# 68328        None  ...    Military             1             1           1
# 68329        None  ...       Civil             1             1           1
#
#       is_civil                                         contractor  \
# 0            1  NPO/PM - Scientific Research Institute for Pre...
# 1            1  NPO/PM - Scientific Research Institute for Pre...
# 2            1  NPO/PM - Scientific Research Institute for Pre...
# 3            1                                           Amsat-NA
# 4            1                                           Amsat-NA
# ...        ...                                                ...
# 68325        1                                           Amsat-NA
# 68326        1                        Chinese Academy of Sciences
# 68327        1                        Chinese Academy of Sciences
# 68328        1  NPO/PM - Scientific Research Institute for Pre...
# 68329        1                                           Amsat-NA
#
#        contractor_country  launch_date  launch_year  launch_site
# 0                  Russia   1957-10-04         1957        TYMSC
# 1                  Russia   1957-10-04         1957        TYMSC
# 2                  Russia   1957-11-03         1957        TYMSC
# 3                     USA   1958-02-01         1958        AFETR
# 4                     USA   1958-03-17         1958        AFETR
# ...                   ...          ...          ...          ...
# 68325                 USA   2026-03-28         2026         RLLB
# 68326               China   2026-03-30         2026          JSC
# 68327               China   2026-03-30         2026          JSC
# 68328              Russia   2026-03-23         2026        PLMSC
# 68329                 USA   2026-04-01         2026        AFETR
#
# [68330 rows x 49 columns]

# %% [markdown]
# ## Primary Question 1: Growth and Decoupling Baseline
# At what year does the present day in-orbit population stop following a legacy linear pattern and transition into a modern accelerating pattern?

# %% [markdown]
# ## **Primary Question 2: High-Risk Distribution by Altitude Band**
# How are high-risk objects (by velocity and kinetic energy) distributed across orbit classes and altitude bands, especially in the 400 - 600 km LEO?

# %% [markdown]
# ## **Primary Question 3: Zombie Concentration by Owner**

# %% [markdown]
# ## **Secondary: Object Type × Operational Status**

# %% [markdown]
# ## **Secondary: User Category Profile**

# %% [markdown]
# ## **Extra Questions!**
