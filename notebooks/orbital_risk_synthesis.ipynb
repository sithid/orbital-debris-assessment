# %% [markdown]
# # **The Master Joiner**
#
# **Intended Purpose**
# Loads both clean files, performs the "Visibility Gap" join, flags the "Zombies," and prepares the final kinetic model. (Output: kinetic_master.csv)

# %%
import pandas as pd
import numpy as np
from IPython.display import Markdown, display

ucs = pd.read_csv('../data/clean/ucs_cleaned.csv')
#sat = pd.read_csv('../data/clean/satcat_cleaned.csv')

# Task List
# 1. Join on NORAD ID
# 2. Overwrite SATCAT proxy mass with HIGH-ACCURACY UCS mass where available
# 3. Identify "Zombies" (Status is in SATCAT but NOT in UCS)
# 4. Export 'kinetic_master.csv'
